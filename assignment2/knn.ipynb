# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
data = pd.read_csv("TCS.csv")
data
# Out:
#             Date Symbol Series  Prev Close     Open     High      Low  \
# 0     2004-08-25    TCS     EQ      850.00  1198.70  1198.70   979.00
# 1     2004-08-26    TCS     EQ      987.95   992.00   997.00   975.30
# 2     2004-08-27    TCS     EQ      979.00   982.40   982.40   958.55
# 3     2004-08-30    TCS     EQ      962.65   969.90   990.00   965.00
# 4     2004-08-31    TCS     EQ      986.75   986.50   990.00   976.00
# ...          ...    ...    ...         ...      ...      ...      ...
# 4134  2021-04-26    TCS     EQ     3109.50  3102.05  3153.00  3088.05
# 4135  2021-04-27    TCS     EQ     3100.80  3106.00  3136.10  3103.00
# 4136  2021-04-28    TCS     EQ     3132.00  3149.95  3151.00  3112.00
# 4137  2021-04-29    TCS     EQ     3124.10  3145.60  3157.35  3105.50
# 4138  2021-04-30    TCS     EQ     3115.25  3099.00  3132.05  3020.00
#
#          Last    Close     VWAP    Volume      Turnover    Trades  \
# 0      985.00   987.95  1008.32  17116372  1.725876e+15       NaN
# 1      976.85   979.00   985.65   5055400  4.982865e+14       NaN
# 2      961.20   962.65   969.94   3830750  3.715586e+14       NaN
# 3      986.40   986.75   982.65   3058151  3.005106e+14       NaN
# 4      987.80   988.10   982.18   2649332  2.602133e+14       NaN
# ...       ...      ...      ...       ...           ...       ...
# 4134  3100.05  3100.80  3122.35   2490260  7.775465e+14   87012.0
# 4135  3132.75  3132.00  3122.18   1471417  4.594036e+14   97077.0
# 4136  3123.00  3124.10  3125.72   1639037  5.123176e+14   76017.0
# 4137  3114.45  3115.25  3130.83   1621395  5.076306e+14   98275.0
# 4138  3040.00  3035.65  3063.19   3072305  9.411057e+14  157829.0
#
#       Deliverable Volume  %Deliverble
# 0                5206360       0.3042
# 1                1294899       0.2561
# 2                 976527       0.2549
# 3                 701664       0.2294
# 4                 695234       0.2624
# ...                  ...          ...
# 4134             1345353       0.5402
# 4135              849767       0.5775
# 4136              847762       0.5172
# 4137              837567       0.5166
# 4138             1942473       0.6323
#
# [4139 rows x 15 columns]

# %%
sliced_x = data.iloc[:,1:3].join(data.iloc[:,4:8])
sliced_x
# Out:
#      Symbol Series     Open     High      Low     Last
# 0       TCS     EQ  1198.70  1198.70   979.00   985.00
# 1       TCS     EQ   992.00   997.00   975.30   976.85
# 2       TCS     EQ   982.40   982.40   958.55   961.20
# 3       TCS     EQ   969.90   990.00   965.00   986.40
# 4       TCS     EQ   986.50   990.00   976.00   987.80
# ...     ...    ...      ...      ...      ...      ...
# 4134    TCS     EQ  3102.05  3153.00  3088.05  3100.05
# 4135    TCS     EQ  3106.00  3136.10  3103.00  3132.75
# 4136    TCS     EQ  3149.95  3151.00  3112.00  3123.00
# 4137    TCS     EQ  3145.60  3157.35  3105.50  3114.45
# 4138    TCS     EQ  3099.00  3132.05  3020.00  3040.00
#
# [4139 rows x 6 columns]

# %%
from sklearn.preprocessing import LabelEncoder
toBeEncode = ['Symbol','Series']
encoder = LabelEncoder()
for col in toBeEncode:
    sliced_x[col]= encoder.fit_transform(sliced_x[col])

# %%
sliced_y = data.iloc[:,3:4]
sliced_y
# Out:
#       Prev Close
# 0         850.00
# 1         987.95
# 2         979.00
# 3         962.65
# 4         986.75
# ...          ...
# 4134     3109.50
# 4135     3100.80
# 4136     3132.00
# 4137     3124.10
# 4138     3115.25
#
# [4139 rows x 1 columns]

# %%
train_x , test_x, train_y , test_y = train_test_split(sliced_x,sliced_y,test_size=0.3)

# %%
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(train_x,train_y)
# Out:
# C:\Users\Digvijay\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neighbors\_classification.py:238: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 2
#       1 knn = KNeighborsClassifier(n_neighbors=10)
# ----> 2 knn.fit(train_x,train_y)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neighbors\_classification.py:238, in KNeighborsClassifier.fit(self, X, y)
#     216 @_fit_context(
#     217     # KNeighborsClassifier.metric is not validated yet
#     218     prefer_skip_nested_validation=False
#     219 )
#     220 def fit(self, X, y):
#     221     """Fit the k-nearest neighbors classifier from the training dataset.
#     222
#     223     Parameters
#    (...)
#     236         The fitted k-nearest neighbors classifier.
#     237     """
# --> 238     return self._fit(X, y)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neighbors\_base.py:500, in NeighborsBase._fit(self, X, y)
#     497 else:
#     498     self.outputs_2d_ = True
# --> 500 check_classification_targets(y)
#     501 self.classes_ = []
#     502 # Using `dtype=np.intp` is necessary since `np.bincount`
#     503 # (called in _classification.py) fails when dealing
#     504 # with a float64 array on 32bit systems.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\multiclass.py:221, in check_classification_targets(y)
#     213 y_type = type_of_target(y, input_name="y")
#     214 if y_type not in [
#     215     "binary",
#     216     "multiclass",
#    (...)
#     219     "multilabel-sequences",
#     220 ]:
# --> 221     raise ValueError(
#     222         f"Unknown label type: {y_type}. Maybe you are trying to fit a "
#     223         "classifier, which expects discrete classes on a "
#     224         "regression target with continuous values."
#     225     )
#
# ValueError: Unknown label type: continuous. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.

# %%
# Prediction
result = knn.predict(test_x)
print(f"Result : {result}")
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[31], line 2
#       1 # Prediction
# ----> 2 result = knn.predict(test_x)
#       3 print(f"Result : {result}")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\neighbors\_classification.py:254, in KNeighborsClassifier.predict(self, X)
#     240 def predict(self, X):
#     241     """Predict the class labels for the provided data.
#     242
#     243     Parameters
#    (...)
#     252         Class labels for each data sample.
#     253     """
# --> 254     check_is_fitted(self, "_fit_method")
#     255     if self.weights == "uniform":
#     256         if self._fit_method == "brute" and ArgKminClassMode.is_usable_for(
#     257             X, self._fit_X, self.metric
#     258         ):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1622, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1619     raise TypeError("%s is not an estimator instance." % (estimator))
#    1621 if not _is_fitted(estimator, attributes, all_or_any):
# -> 1622     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This KNeighborsClassifier instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
# Accuracy
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(test_y,result)
print(f"Accuracy: {accuracy}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 3
#       1 # Accuracy
#       2 from sklearn.metrics import accuracy_score
# ----> 3 accuracy = accuracy_score(test_y,result)
#       4 print(f"Accuracy: {accuracy}")
#
# NameError: name 'result' is not defined

# %%
# Precision
from sklearn.metrics import precision_score
precision = precision_score(test_y,result,average='weighted')
print(f"Precision: {precision}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 3
#       1 # Precision
#       2 from sklearn.metrics import precision_score
# ----> 3 precision = precision_score(test_y,result,average='weighted')
#       4 print(f"Precision: {precision}")
#
# NameError: name 'result' is not defined

# %%
# Recall 
from sklearn.metrics import recall_score
recall = recall_score(test_y,result,average='weighted')
print(f"Recall: {recall}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 3
#       1 # Recall
#       2 from sklearn.metrics import recall_score
# ----> 3 recall = recall_score(test_y,result,average='weighted')
#       4 print(f"Recall: {recall}")
#
# NameError: name 'result' is not defined

# %%
# F1
from sklearn.metrics import f1_score
f1 = f1_score(test_y,result,average='weighted')
print(f"F1: {f1}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 3
#       1 # F1
#       2 from sklearn.metrics import f1_score
# ----> 3 f1 = f1_score(test_y,result,average='weighted')
#       4 print(f"F1: {f1}")
#
# NameError: name 'result' is not defined
