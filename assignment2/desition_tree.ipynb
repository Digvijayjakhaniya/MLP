# %%
import pandas as pd

# %%
data = pd.read_csv("TCS.csv")
data
# Out:
#             Date Symbol Series  Prev Close     Open     High      Low  \
# 0     2004-08-25    TCS     EQ      850.00  1198.70  1198.70   979.00
# 1     2004-08-26    TCS     EQ      987.95   992.00   997.00   975.30
# 2     2004-08-27    TCS     EQ      979.00   982.40   982.40   958.55
# 3     2004-08-30    TCS     EQ      962.65   969.90   990.00   965.00
# 4     2004-08-31    TCS     EQ      986.75   986.50   990.00   976.00
# ...          ...    ...    ...         ...      ...      ...      ...
# 4134  2021-04-26    TCS     EQ     3109.50  3102.05  3153.00  3088.05
# 4135  2021-04-27    TCS     EQ     3100.80  3106.00  3136.10  3103.00
# 4136  2021-04-28    TCS     EQ     3132.00  3149.95  3151.00  3112.00
# 4137  2021-04-29    TCS     EQ     3124.10  3145.60  3157.35  3105.50
# 4138  2021-04-30    TCS     EQ     3115.25  3099.00  3132.05  3020.00
#
#          Last    Close     VWAP    Volume      Turnover    Trades  \
# 0      985.00   987.95  1008.32  17116372  1.725876e+15       NaN
# 1      976.85   979.00   985.65   5055400  4.982865e+14       NaN
# 2      961.20   962.65   969.94   3830750  3.715586e+14       NaN
# 3      986.40   986.75   982.65   3058151  3.005106e+14       NaN
# 4      987.80   988.10   982.18   2649332  2.602133e+14       NaN
# ...       ...      ...      ...       ...           ...       ...
# 4134  3100.05  3100.80  3122.35   2490260  7.775465e+14   87012.0
# 4135  3132.75  3132.00  3122.18   1471417  4.594036e+14   97077.0
# 4136  3123.00  3124.10  3125.72   1639037  5.123176e+14   76017.0
# 4137  3114.45  3115.25  3130.83   1621395  5.076306e+14   98275.0
# 4138  3040.00  3035.65  3063.19   3072305  9.411057e+14  157829.0
#
#       Deliverable Volume  %Deliverble
# 0                5206360       0.3042
# 1                1294899       0.2561
# 2                 976527       0.2549
# 3                 701664       0.2294
# 4                 695234       0.2624
# ...                  ...          ...
# 4134             1345353       0.5402
# 4135              849767       0.5775
# 4136              847762       0.5172
# 4137              837567       0.5166
# 4138             1942473       0.6323
#
# [4139 rows x 15 columns]

# %%
sliced_x = data.iloc[:,1:3].join(data.iloc[:,4:8])
sliced_x
# Out:
#      Symbol Series     Open     High      Low     Last
# 0       TCS     EQ  1198.70  1198.70   979.00   985.00
# 1       TCS     EQ   992.00   997.00   975.30   976.85
# 2       TCS     EQ   982.40   982.40   958.55   961.20
# 3       TCS     EQ   969.90   990.00   965.00   986.40
# 4       TCS     EQ   986.50   990.00   976.00   987.80
# ...     ...    ...      ...      ...      ...      ...
# 4134    TCS     EQ  3102.05  3153.00  3088.05  3100.05
# 4135    TCS     EQ  3106.00  3136.10  3103.00  3132.75
# 4136    TCS     EQ  3149.95  3151.00  3112.00  3123.00
# 4137    TCS     EQ  3145.60  3157.35  3105.50  3114.45
# 4138    TCS     EQ  3099.00  3132.05  3020.00  3040.00
#
# [4139 rows x 6 columns]

# %%
sliced_y = data.iloc[:,3:4]
sliced_y
# Out:
#       Prev Close
# 0         850.00
# 1         987.95
# 2         979.00
# 3         962.65
# 4         986.75
# ...          ...
# 4134     3109.50
# 4135     3100.80
# 4136     3132.00
# 4137     3124.10
# 4138     3115.25
#
# [4139 rows x 1 columns]

# %%
from sklearn.preprocessing import LabelEncoder
toBeEncoded =  ['Symbol','Series']
encoder = LabelEncoder()
for col in toBeEncoded:
    sliced_x[col] = encoder.fit_transform(sliced_x[col])

# %%
# train test split
from sklearn.model_selection import train_test_split
train_x , test_x , train_y, test_y = train_test_split(sliced_x,sliced_y,test_size=0.3)

# %%
# Desition Tree classifier
from sklearn.tree import DecisionTreeClassifier

# %%
classifier = DecisionTreeClassifier()
classifier.fit(train_x,train_y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 classifier = DecisionTreeClassifier()
# ----> 2 classifier.fit(train_x,train_y)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\tree\_classes.py:1009, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     978 @_fit_context(prefer_skip_nested_validation=True)
#     979 def fit(self, X, y, sample_weight=None, check_input=True):
#     980     """Build a decision tree classifier from the training set (X, y).
#     981
#     982     Parameters
#    (...)
#    1006         Fitted estimator.
#    1007     """
# -> 1009     super()._fit(
#    1010         X,
#    1011         y,
#    1012         sample_weight=sample_weight,
#    1013         check_input=check_input,
#    1014     )
#    1015     return self
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\tree\_classes.py:294, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     291 self.n_outputs_ = y.shape[1]
#     293 if is_classification:
# --> 294     check_classification_targets(y)
#     295     y = np.copy(y)
#     297     self.classes_ = []
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\multiclass.py:221, in check_classification_targets(y)
#     213 y_type = type_of_target(y, input_name="y")
#     214 if y_type not in [
#     215     "binary",
#     216     "multiclass",
#    (...)
#     219     "multilabel-sequences",
#     220 ]:
# --> 221     raise ValueError(
#     222         f"Unknown label type: {y_type}. Maybe you are trying to fit a "
#     223         "classifier, which expects discrete classes on a "
#     224         "regression target with continuous values."
#     225     )
#
# ValueError: Unknown label type: continuous. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.

# %%
# Prediction
result = classifier.predict(test_x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 2
#       1 # Prediction
# ----> 2 result = classifier.predict(test_x)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\tree\_classes.py:530, in BaseDecisionTree.predict(self, X, check_input)
#     528 check_is_fitted(self)
#     529 X = self._validate_X_predict(X, check_input)
# --> 530 proba = self.tree_.predict(X)
#     531 n_samples = X.shape[0]
#     533 # Classification
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'tree_'

# %%
# For Plotting
from sklearn import tree
tree.plot_tree(classifier,feature_names=sliced_x.columns)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 3
#       1 # For Plotting
#       2 from sklearn import tree
# ----> 3 tree.plot_tree(classifier,feature_names=sliced_x.columns)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\tree\_export.py:211, in plot_tree(decision_tree, max_depth, feature_names, class_names, label, filled, impurity, node_ids, proportion, rounded, precision, ax, fontsize)
#     196 check_is_fitted(decision_tree)
#     198 exporter = _MPLTreeExporter(
#     199     max_depth=max_depth,
#     200     feature_names=feature_names,
#    (...)
#     209     fontsize=fontsize,
#     210 )
# --> 211 return exporter.export(decision_tree, ax=ax)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\tree\_export.py:644, in _MPLTreeExporter.export(self, decision_tree, ax)
#     642 ax.clear()
#     643 ax.set_axis_off()
# --> 644 my_tree = self._make_tree(0, decision_tree.tree_, decision_tree.criterion)
#     645 draw_tree = buchheim(my_tree)
#     647 # important to make sure we're still
#     648 # inside the axis after drawing the box
#     649 # this makes sense because the width of a box
#     650 # is about the same as the distance between boxes
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'tree_'

# %%
# accuracy
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(result,test_y)
print(f"Accuracy: {accuracy}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 3
#       1 # accuracy
#       2 from sklearn.metrics import accuracy_score
# ----> 3 accuracy = accuracy_score(result,test_y)
#       4 print(f"Accuracy: {accuracy}")
#
# NameError: name 'result' is not defined

# %%
# Presition
from sklearn.metrics import precision_score
precision = precision_score(result,test_y,average='weighted')
print(f"Precision: {precision}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 3
#       1 # Presition
#       2 from sklearn.metrics import precision_score
# ----> 3 precision = precision_score(result,test_y,average='weighted')
#       4 print(f"Precision: {precision}")
#
# NameError: name 'result' is not defined

# %%
# Recall
from sklearn.metrics import recall_score
recall = recall_score(result,test_y,average='weighted')
print(f"Recall: {recall}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 3
#       1 # Recall
#       2 from sklearn.metrics import recall_score
# ----> 3 recall = recall_score(result,test_y,average='weighted')
#       4 print(f"Recall: {recall}")
#
# NameError: name 'result' is not defined

# %%
# Cell
from sklearn.metrics import f1_score
f1 = f1_score(result,test_y,average='weighted')
print(f"F1: {f1}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 3
#       1 # Cell
#       2 from sklearn.metrics import f1_score
# ----> 3 f1 = f1_score(result,test_y,average='weighted')
#       4 print(f"F1: {f1}")
#
# NameError: name 'result' is not defined
